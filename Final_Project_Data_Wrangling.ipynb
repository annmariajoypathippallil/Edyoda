# %%
import pandas as pd

# %% [markdown]
# 1.importing data set

# %%
# url = 'https://raw.githubusercontent.com/SR1608/Datasets/main/covid-data.csv'
data = pd.read_csv('https://raw.githubusercontent.com/SR1608/Datasets/main/covid-data.csv')
data.head(5)
# Out:
#   iso_code continent     location      date  total_cases  new_cases  \
# 0      AFG      Asia  Afghanistan  31/12/19          NaN        0.0
# 1      AFG      Asia  Afghanistan  01/01/20          NaN        0.0
# 2      AFG      Asia  Afghanistan  02/01/20          NaN        0.0
# 3      AFG      Asia  Afghanistan  03/01/20          NaN        0.0
# 4      AFG      Asia  Afghanistan  04/01/20          NaN        0.0
#
#    new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 0                 NaN           NaN         0.0                  NaN  ...
# 1                 NaN           NaN         0.0                  NaN  ...
# 2                 NaN           NaN         0.0                  NaN  ...
# 3                 NaN           NaN         0.0                  NaN  ...
# 4                 NaN           NaN         0.0                  NaN  ...
#
#    gdp_per_capita  extreme_poverty  cardiovasc_death_rate  \
# ...

# %% [markdown]
# 2.High level understanding of data

# %%
# a.Find no. of rows and cloumns in a dataset


num_rows, num_columns = data.shape

print(f"Number of rows: {num_rows}")
print(f"Number of columns: {num_columns}")
# Out:
# Number of rows: 57394
# Number of columns: 49

# %%
# b.Data type of columns
column_data_types = data.dtypes
print("Data type of columns", column_data_types)
# Out:
# Data type of columns iso_code                               object
# continent                              object
# location                               object
# date                                   object
# total_cases                           float64
# new_cases                             float64
# new_cases_smoothed                    float64
# total_deaths                          float64
# new_deaths                            float64
# new_deaths_smoothed                   float64
# total_cases_per_million               float64
# new_cases_per_million                 float64
# new_cases_smoothed_per_million        float64
# total_deaths_per_million              float64
# new_deaths_per_million                float64
# new_deaths_smoothed_per_million       float64
# reproduction_rate                     float64
# icu_patients                          float64
# icu_patients_per_million              float64
# hosp_patients                         float64
# ...

# %%
# c.info of data frames
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 57394 entries, 0 to 57393
# Data columns (total 49 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   iso_code                            57071 non-null  object
#  1   continent                           56748 non-null  object
#  2   location                            57394 non-null  object
#  3   date                                57394 non-null  object
#  4   total_cases                         53758 non-null  float64
#  5   new_cases                           56465 non-null  float64
#  6   new_cases_smoothed                  55652 non-null  float64
#  7   total_deaths                        44368 non-null  float64
#  8   new_deaths                          56465 non-null  float64
#  9   new_deaths_smoothed                 55652 non-null  float64
#  10  total_cases_per_million             53471 non-null  float64
# ...

# %%
#c. Description of data frames
data.describe()
# Out:
#         total_cases      new_cases  new_cases_smoothed  total_deaths  \
# count  5.375800e+04   56465.000000        55652.000000  4.436800e+04
# mean   1.677974e+05    1953.576941         1920.431953  6.858639e+03
# std    1.693038e+06   18269.650340        17777.391785  5.578081e+04
# min    1.000000e+00   -8261.000000         -552.000000  1.000000e+00
# 25%    1.800000e+02       0.000000            0.857000  1.300000e+01
# 50%    2.070000e+03      14.000000           19.429000  8.400000e+01
# 75%    2.235675e+04     235.000000          245.286000  7.270000e+02
# max    5.515465e+07  646281.000000       584981.857000  1.328537e+06
#
#          new_deaths  new_deaths_smoothed  total_cases_per_million  \
# count  56465.000000         55652.000000             53471.000000
# mean      47.054317            46.835439              3139.099982
# std      390.853776           378.272794              6183.455260
# min    -1918.000000          -232.143000                 0.001000
# ...

# %% [markdown]
# 3.Low level data understanding

# %%
# a.Find cound of unique values in location column

unique_location_count = data["location"].nunique()
print(f"Count of unique values in 'location' column: {unique_location_count}")
# Out:
# Count of unique values in 'location' column: 216

# %%
# b.find which continent has the maximum number of frequency using values count
continent_counts = data['continent'].value_counts()
max_frequency_continent = continent_counts.idxmax()
max_frequency_count = continent_counts.max()
print(f"The continent with the maximum frequency is '{max_frequency_continent}' with a count of {max_frequency_count}.")
# Out:
# The continent with the maximum frequency is 'Europe' with a count of 14828.

# %%
# c.Find maximum and mean_value in total_cases

maximum_total_cases=data["total_cases"].max()
mean_total_cases = data["total_cases"].mean()
print(f"Maximum of 'total_cases':{maximum_total_cases}\nMean of 'total_cases':{mean_total_cases}")
# Out:
# Maximum of 'total_cases':55154651.0
# Mean of 'total_cases':167797.3688753302

# %%
# d. find 25%,50% and 70% quartile value in 'total_deaths'

quartiles = [0.25, 0.50, 0.75]
quartile_values = data['total_deaths'].quantile(quartiles)
for q, value in zip(quartiles, quartile_values):
    print(f"{int(q * 100)}% Quartile: {value}")
# Out:
# 25% Quartile: 13.0
# 50% Quartile: 84.0
# 75% Quartile: 727.0

# %%
# e. find which continent has maximum human_development_index

max_hdi_idx = data.groupby('continent')['human_development_index'].idxmax()
max_hdi_continents = data.loc[max_hdi_idx]
print("Continent(s) with maximum 'human_development_index':")
for index, row in max_hdi_continents.iterrows():
    print(f"{row['continent']}: {row['human_development_index']}")
# Out:
# Continent(s) with maximum 'human_development_index':
# Africa: 0.797
# Asia: 0.933
# Europe: 0.953
# North America: 0.926
# Oceania: 0.939
# South America: 0.843

# %%
# f.find which continent has minimum "gdp_per_capita "
continent_min_gdp = data.groupby('continent')['gdp_per_capita'].min()

# Find the continent with the minimum gdp_per_data.
continent_with_min_gdp = continent_min_gdp.idxmin()

print("Continent with Minimum GDP per Data:", continent_with_min_gdp)
# Out:
# Continent with Minimum GDP per Data: Africa

# %%
# 4. Filter the dataframe with only this columns ['continent', 'location', 'date','total_cases','total_deaths','gdp_per_ca pita',' human_development_index'] and update the data frame.

selected_columns = ['continent', 'location', 'date', 'total_cases', 'total_deaths', 'gdp_per_capita', 'human_development_index']
filtered_data = data[selected_columns]
filtered_data.to_csv('filtered_dataset.csv', index=False)

# %%
filtered_data
# Out:
#       continent       location      date  total_cases  total_deaths  \
# 0          Asia    Afghanistan  31/12/19          NaN           NaN
# 1          Asia    Afghanistan  01/01/20          NaN           NaN
# 2          Asia    Afghanistan  02/01/20          NaN           NaN
# 3          Asia    Afghanistan  03/01/20          NaN           NaN
# 4          Asia    Afghanistan  04/01/20          NaN           NaN
# ...         ...            ...       ...          ...           ...
# 57389       NaN  International  13/11/20        696.0           7.0
# 57390       NaN  International  14/11/20        696.0           7.0
# 57391       NaN  International  15/11/20        696.0           7.0
# 57392       NaN  International  16/11/20        696.0           7.0
# 57393       NaN  International  17/11/20        696.0           7.0
#
#        gdp_per_capita  human_development_index
# 0            1803.987                    0.498
# 1            1803.987                    0.498
# ...

# %% [markdown]
# 5. Data Cleaning

# %%
# a. Remove all duplicate observations
datas = data.drop_duplicates()
datas
# Out:
#       iso_code continent     location      date  total_cases  new_cases  \
# 0          AFG      Asia  Afghanistan  31/12/19          0.0        0.0
# 1          AFG      Asia  Afghanistan  01/01/20          0.0        0.0
# 2          AFG      Asia  Afghanistan  02/01/20          0.0        0.0
# 3          AFG      Asia  Afghanistan  03/01/20          0.0        0.0
# 4          AFG      Asia  Afghanistan  04/01/20          0.0        0.0
# ...        ...       ...          ...       ...          ...        ...
# 56743      ZWE    Africa     Zimbabwe  13/11/20       8696.0       29.0
# 56744      ZWE    Africa     Zimbabwe  14/11/20       8765.0       69.0
# 56745      ZWE    Africa     Zimbabwe  15/11/20       8786.0       21.0
# 56746      ZWE    Africa     Zimbabwe  16/11/20       8786.0        0.0
# 56747      ZWE    Africa     Zimbabwe  17/11/20       8897.0      111.0
#
#        new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# ...

# %%
# b. Find missing values in all columns
missing_values = data.isnull().sum()
missing_values
# Out:
# iso_code                              0
# continent                             0
# location                              0
# date                                  0
# total_cases                           0
# new_cases                             0
# new_cases_smoothed                    0
# total_deaths                          0
# new_deaths                            0
# new_deaths_smoothed                   0
# total_cases_per_million               0
# new_cases_per_million                 0
# new_cases_smoothed_per_million        0
# total_deaths_per_million              0
# new_deaths_per_million                0
# new_deaths_smoothed_per_million       0
# reproduction_rate                     0
# icu_patients                          0
# icu_patients_per_million              0
# hosp_patients                         0
# hosp_patients_per_million             0
# weekly_icu_admissions                 0
# weekly_icu_admissions_per_million     0
# ...

# %%
# c. Remove all observations where the continent column value is missing
datas = data.dropna(subset=['continent'])

datas
# Out:
#       iso_code continent     location      date  total_cases  new_cases  \
# 0          AFG      Asia  Afghanistan  31/12/19          0.0        0.0
# 1          AFG      Asia  Afghanistan  01/01/20          0.0        0.0
# 2          AFG      Asia  Afghanistan  02/01/20          0.0        0.0
# 3          AFG      Asia  Afghanistan  03/01/20          0.0        0.0
# 4          AFG      Asia  Afghanistan  04/01/20          0.0        0.0
# ...        ...       ...          ...       ...          ...        ...
# 56743      ZWE    Africa     Zimbabwe  13/11/20       8696.0       29.0
# 56744      ZWE    Africa     Zimbabwe  14/11/20       8765.0       69.0
# 56745      ZWE    Africa     Zimbabwe  15/11/20       8786.0       21.0
# 56746      ZWE    Africa     Zimbabwe  16/11/20       8786.0        0.0
# 56747      ZWE    Africa     Zimbabwe  17/11/20       8897.0      111.0
#
#        new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# ...

# %%
# d. Fill all missing values with 0
datas = data.fillna(0)
datas
# Out:
#       iso_code continent     location      date  total_cases  new_cases  \
# 0          AFG      Asia  Afghanistan  31/12/19          0.0        0.0
# 1          AFG      Asia  Afghanistan  01/01/20          0.0        0.0
# 2          AFG      Asia  Afghanistan  02/01/20          0.0        0.0
# 3          AFG      Asia  Afghanistan  03/01/20          0.0        0.0
# 4          AFG      Asia  Afghanistan  04/01/20          0.0        0.0
# ...        ...       ...          ...       ...          ...        ...
# 56743      ZWE    Africa     Zimbabwe  13/11/20       8696.0       29.0
# 56744      ZWE    Africa     Zimbabwe  14/11/20       8765.0       69.0
# 56745      ZWE    Africa     Zimbabwe  15/11/20       8786.0       21.0
# 56746      ZWE    Africa     Zimbabwe  16/11/20       8786.0        0.0
# 56747      ZWE    Africa     Zimbabwe  17/11/20       8897.0      111.0
#
#        new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# ...

# %%
# Save the cleaned DataFrame to a new CSV file
data.to_csv('cleaned_dataset.csv', index=False)

# %%
data
# Out:
#       iso_code continent     location      date  total_cases  new_cases  \
# 0          AFG      Asia  Afghanistan  31/12/19          0.0        0.0
# 1          AFG      Asia  Afghanistan  01/01/20          0.0        0.0
# 2          AFG      Asia  Afghanistan  02/01/20          0.0        0.0
# 3          AFG      Asia  Afghanistan  03/01/20          0.0        0.0
# 4          AFG      Asia  Afghanistan  04/01/20          0.0        0.0
# ...        ...       ...          ...       ...          ...        ...
# 56743      ZWE    Africa     Zimbabwe  13/11/20       8696.0       29.0
# 56744      ZWE    Africa     Zimbabwe  14/11/20       8765.0       69.0
# 56745      ZWE    Africa     Zimbabwe  15/11/20       8786.0       21.0
# 56746      ZWE    Africa     Zimbabwe  16/11/20       8786.0        0.0
# 56747      ZWE    Africa     Zimbabwe  17/11/20       8897.0      111.0
#
#        new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# ...

# %% [markdown]
# 6. Date time format:

# %%
# a. Convert the "date" column to datetime format
data['date'] = pd.to_datetime(data['date'])

# b. Create a new "month" column by extracting the month data from the "date" column
data['month'] = data['date'].dt.month

# Save the updated DataFrame to a new CSV file
data.to_csv('updated_dataset.csv', index=False)

data
# Out:
# C:\Users\Ann\AppData\Local\Temp\ipykernel_7936\3951296706.py:2: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   data['date'] = pd.to_datetime(data['date'])
#       iso_code continent     location       date  total_cases  new_cases  \
# 0          AFG      Asia  Afghanistan 2019-12-31          0.0        0.0
# 1          AFG      Asia  Afghanistan 2020-01-01          0.0        0.0
# 2          AFG      Asia  Afghanistan 2020-02-01          0.0        0.0
# 3          AFG      Asia  Afghanistan 2020-03-01          0.0        0.0
# 4          AFG      Asia  Afghanistan 2020-04-01          0.0        0.0
# ...        ...       ...          ...        ...          ...        ...
# 56743      ZWE    Africa     Zimbabwe 2020-11-13       8696.0       29.0
# 56744      ZWE    Africa     Zimbabwe 2020-11-14       8765.0       69.0
# ...

# %% [markdown]
# 7. Data Aggregation:

# %%
# a. Find the max value in all columns using groupby on "continent" column
df_groupby = data.groupby('continent').max().reset_index()

# Display the new DataFrame with max values by continent
print(df_groupby)
# Out:
#        continent iso_code                      location       date  \
# 0         Africa      ZWE                      Zimbabwe 2020-12-11
# 1           Asia      YEM                         Yemen 2020-12-11
# 2         Europe      VAT                       Vatican 2020-12-11
# 3  North America      VIR  United States Virgin Islands 2020-12-11
# 4        Oceania      WLF             Wallis and Futuna 2020-12-11
# 5  South America      VEN                     Venezuela 2020-12-11
#
#    total_cases  new_cases  new_cases_smoothed  total_deaths  new_deaths  \
# 0     752269.0    13944.0           12583.714       20314.0       572.0
# 1    8874290.0    97894.0           93198.571      130519.0      2003.0
# 2    1991233.0    86852.0           54868.571       52147.0      2004.0
# 3   11205486.0   184813.0          156419.143      247220.0      4928.0
# 4      27750.0     1384.0             551.714         907.0        59.0
# ...

# %% [markdown]
# 8. Feature Engineering:

# %%
# Create the new feature 'total_deaths_to_total_cases'
data['total_deaths_to_total_cases'] = data['total_deaths'] / data['total_cases']

# Save the updated DataFrame to a new CSV file
data.to_csv('updated_dataset.csv', index=False)
data
# Out:
#       iso_code continent       location      date  total_cases  new_cases  \
# 0          AFG      Asia    Afghanistan  31/12/19          NaN        0.0
# 1          AFG      Asia    Afghanistan  01/01/20          NaN        0.0
# 2          AFG      Asia    Afghanistan  02/01/20          NaN        0.0
# 3          AFG      Asia    Afghanistan  03/01/20          NaN        0.0
# 4          AFG      Asia    Afghanistan  04/01/20          NaN        0.0
# ...        ...       ...            ...       ...          ...        ...
# 57389      NaN       NaN  International  13/11/20        696.0        NaN
# 57390      NaN       NaN  International  14/11/20        696.0        NaN
# 57391      NaN       NaN  International  15/11/20        696.0        NaN
# 57392      NaN       NaN  International  16/11/20        696.0        NaN
# 57393      NaN       NaN  International  17/11/20        696.0        NaN
#
#        new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# ...

# %% [markdown]
# 9. Data Visualization:

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# a. Univariate analysis on 'gdp_per_capita' using a histogram
plt.figure(figsize=(10, 5))
sns.distplot(data['gdp_per_capita'], kde=False, bins=20)
plt.title('Histogram of GDP per Capita')
plt.xlabel('GDP per Capita')
plt.ylabel('Frequency')
plt.show()
# Out:
# C:\Users\Ann\AppData\Local\Temp\ipykernel_9784\520330492.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data['gdp_per_capita'], kde=False, bins=20)

# %%
# b. Scatter plot of 'total_cases' vs 'gdp_per_capita'
plt.figure(figsize=(10, 5))
sns.scatterplot(x='gdp_per_capita', y='total_cases', data=data)
plt.title('Scatter Plot of Total Cases vs GDP per Capita')
plt.xlabel('GDP per Capita')
plt.ylabel('Total Cases')
plt.show()

# %%
# c. Pairplot on df_groupby dataset
df_groupby = data.groupby('continent').max().reset_index()
sns.pairplot(df_groupby)
plt.show()
# Out:
# c:\Users\Ann\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
# d. Bar plot of 'continent' column with 'total_cases'
plt.figure(figsize=(12, 6))
sns.catplot(x='continent', y='total_cases', kind='bar', data=data)
plt.title('Total Cases by Continent')
plt.xlabel('Continent')
plt.ylabel('Total Cases')
plt.xticks(rotation=45)
plt.show()
# Out:
# c:\Users\Ann\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
file_path = "E:/Edyoda/your_dataframe.csv"

# Use the to_csv function to save the DataFrame to a CSV file
data.to_csv(file_path, index=False)
